# %%
# !apt install ffmpeg

# %%
pip install spleeter

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd gdrive/My Drive/Insubria/Magistrale/Tesi/project_folder/NicolaProject/autovc

# %%
import os
from IPython.display import Audio

input = 'v1_Pak_70/id0059/English/fLmv5exbzmg/00108.wav'
sp = 'spleeter:2stems'
output_folder = 'output'

os.environ['IN'] = input
os.environ['SPL'] = sp
os.environ['OUT'] = output_folder

Audio(input)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !mkdir -p $OUT
# !spleeter separate -p $SPL -o $OUT $IN

# %%
Audio('output/00108/vocals.wav')
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio('output/00108/accompaniment.wav')
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
